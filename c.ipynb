# %%
from tkinter  import *

root = Tk()

root.title("CALCULATOR")
root.geometry("590x630")

root.configure(bg="black")

def click(event):

    global value


    text = event.widget.cget("text")
    if screenValue.get().isdigit():
        int(display.update())

def click(event):
    
    global screenValue

    text = event.widget.cget("text")

    if text == "=":

        if screenValue.get().isdigit():
            value = int(screenValue.get())

        else:
            try:
                value = eval(screenValue.get())
            
            except Exception as e:
                value= "ERROR"

        screenValue.set(value)
        display.update()

    elif text == "AC":
        screenValue.set(" ")

    else:
        screenValue.set((screenValue.get()) + (text))
        display.update()

screenValue = StringVar()
screenValue.set(" ")

display = Entry(root, textvariable=screenValue, font="arial 38", relief=SUNKEN)
display.pack(pady=20)


# Creating Buttons
b = Button(root, text="AC", font="arial 20 bold", height=2, width=5, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=2, y=120)
b.bind("<Button-1>", click)

b = Button(root, text="%", font="arial 20 bold", height=2, width=5, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=108, y=120)
b.bind("<Button-1>", click)

b = Button(root, text="x²", font="arial 20 bold", height=2, width=5, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=212, y=120)
b.bind("<Button-1>", click)

b = Button(root, text="x³", font="arial 20 bold", height=2, width=5, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=317, y=120)
b.bind("<Button-1>", click)

b = Button(root, text="+", font="arial 20 bold", height=2, width=8, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=419, y=120)
b.bind("<Button-1>", click)

b = Button(root, text="9", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=3, y=220)
b.bind("<Button-1>", click)

b = Button(root, text="8", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=140, y=220)
b.bind("<Button-1>", click)

b = Button(root, text="7", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=278, y=220)
b.bind("<Button-1>", click)

b = Button(root, text="-", font="arial 20 bold", height=2, width=8, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=420, y=220)
b.bind("<Button-1>", click)

# Button 6,5,4,x
b = Button(root, text="6", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=3, y=320)
b.bind("<Button-1>", click)

b = Button(root, text="5", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=140, y=320)
b.bind("<Button-1>", click)

b = Button(root, text="4", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=278, y=320)
b.bind("<Button-1>", click)

b = Button(root, text="*", font="arial 20 bold", height=2, width=8, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=420, y=320)
b.bind("<Button-1>", click)

b = Button(root, text="3", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=3, y=420)
b.bind("<Button-1>", click)

b = Button(root, text="2", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=140, y=420)
b.bind("<Button-1>", click)

b = Button(root, text="1", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=278, y=420)
b.bind("<Button-1>", click)

b = Button(root, text="/", font="arial 20 bold", height=2, width=8, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=420, y=420)
b.bind("<Button-1>", click)

b = Button(root, text="=", font="arial 20 bold", height=2, width=8, bd=2, fg="black", bg="grey", relief=SUNKEN)
b.place(x=420, y=518)
b.bind("<Button-1>", click)

b= Button(root, text=".", font="arial 20 bold", height=2, width=7, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=275, y=518)
b.bind("<Button-1>", click)

b = Button(root, text="0", font="arial  20 bold", height=2, width=15, bd=2, fg="white", bg="grey", relief=SUNKEN)
b.place(x=3, y=518)
b.bind("<Button-1>", click)

root.mainloop()
